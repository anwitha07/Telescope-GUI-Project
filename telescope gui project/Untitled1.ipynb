# %%
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import*


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1155, 772)
        Form.setStyleSheet("background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 rgba(0, 0, 0, 255), stop:1 rgba(255, 255, 255, 255));\n"
"")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(220, 30, 761, 61))
        self.label.setStyleSheet("font: 75 24pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 48, 7);")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(90, 130, 221, 41))
        self.label_2.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(90, 190, 221, 41))
        self.label_3.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(90, 260, 221, 41))
        self.label_4.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(90, 320, 221, 41))
        self.label_5.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(90, 380, 221, 41))
        self.label_6.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(90, 440, 221, 41))
        self.label_7.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(90, 500, 221, 41))
        self.label_8.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(90, 560, 221, 41))
        self.label_9.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(90, 620, 221, 41))
        self.label_10.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(90, 680, 221, 41))
        self.label_11.setStyleSheet("font: 75 20pt \"MS Shell Dlg 2\";\n"
"color:rgb(0, 255, 0)")
        self.label_11.setObjectName("label_11")
        self.lineEdit_4 = QtWidgets.QLineEdit(Form)
        self.lineEdit_4.setGeometry(QtCore.QRect(390, 130, 331, 41))
        self.lineEdit_4.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_4.setText("")
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(820, 270, 271, 71))
        self.pushButton.setStyleSheet("font: 75 italic 26pt \"Palatino Linotype\";\n"
"color: rgb(255, 255, 255);\n"
"background-color: rgb(17, 17, 17);")
        self.pushButton.setObjectName("pushButton")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(820, 450, 271, 91))
        self.label_12.setStyleSheet("font: 75 italic 26pt \"MS Serif\";\n"
"color: rgb(255, 255, 255);\n"
"background-color: rgb(142, 83, 200);")
        self.label_12.setObjectName("label_12")
        self.lineEdit_5 = QtWidgets.QLineEdit(Form)
        self.lineEdit_5.setGeometry(QtCore.QRect(390, 190, 331, 41))
        self.lineEdit_5.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_5.setText("")
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.lineEdit_6 = QtWidgets.QLineEdit(Form)
        self.lineEdit_6.setGeometry(QtCore.QRect(390, 310, 331, 41))
        self.lineEdit_6.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_6.setText("")
        self.lineEdit_6.setObjectName("lineEdit_6")
        self.lineEdit_7 = QtWidgets.QLineEdit(Form)
        self.lineEdit_7.setGeometry(QtCore.QRect(410, 680, 331, 41))
        self.lineEdit_7.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_7.setText("")
        self.lineEdit_7.setObjectName("lineEdit_7")
        self.lineEdit_8 = QtWidgets.QLineEdit(Form)
        self.lineEdit_8.setGeometry(QtCore.QRect(390, 250, 331, 41))
        self.lineEdit_8.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_8.setText("")
        self.lineEdit_8.setObjectName("lineEdit_8")
        self.lineEdit_9 = QtWidgets.QLineEdit(Form)
        self.lineEdit_9.setGeometry(QtCore.QRect(390, 370, 331, 41))
        self.lineEdit_9.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_9.setText("")
        self.lineEdit_9.setObjectName("lineEdit_9")
        self.lineEdit_10 = QtWidgets.QLineEdit(Form)
        self.lineEdit_10.setGeometry(QtCore.QRect(400, 430, 331, 41))
        self.lineEdit_10.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_10.setText("")
        self.lineEdit_10.setObjectName("lineEdit_10")
        self.lineEdit_11 = QtWidgets.QLineEdit(Form)
        self.lineEdit_11.setGeometry(QtCore.QRect(390, 490, 331, 41))
        self.lineEdit_11.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_11.setText("")
        self.lineEdit_11.setObjectName("lineEdit_11")
        self.lineEdit_12 = QtWidgets.QLineEdit(Form)
        self.lineEdit_12.setGeometry(QtCore.QRect(390, 550, 331, 41))
        self.lineEdit_12.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_12.setText("")
        self.lineEdit_12.setObjectName("lineEdit_12")
        self.lineEdit_13 = QtWidgets.QLineEdit(Form)
        self.lineEdit_13.setGeometry(QtCore.QRect(400, 610, 331, 41))
        self.lineEdit_13.setStyleSheet("font: 14pt \"MS Shell Dlg 2\";\n"
"color: rgb(255, 0, 0);")
        self.lineEdit_13.setText("")
        self.lineEdit_13.setObjectName("lineEdit_13")
        
        self.pushButton.clicked.connect(self.predictclass)
        self.pushButton.clicked.connect(self.login)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def predictclass(self):
        import pandas as pd
        import sklearn
        from sklearn.model_selection import train_test_split
        from sklearn.linear_model import LogisticRegression
        
        path="C:\\Users\\HEMASHRI H M\\Downloads\\GSSS_workshop\\7_telescopespectrumclassification\\train_dataset.csv"

        data=pd.read_csv(path)

        print(data)
        print(data.info())

        inputs=data.drop('class','columns')
        output=data.drop(['fLength','fWidth','fSize','fConc','fConc1','fAsym','fM3Long','fM3Trans','fAlpha','fDist'],'columns')

        print(inputs)
        print(output)
        x_train,x_test,y_train,y_test=train_test_split(inputs,output,train_size=0.8)
        print(x_train)
        print(x_test)
        print(y_train)
        print(y_test)
        model=LogisticRegression()
        model.fit(x_train,y_train)

        y_pred=model.predict(x_test)
        print(y_pred)
        print(y_test)
        

        from sklearn.metrics import confusion_matrix

        cm=confusion_matrix(y_test,y_pred)
        print(cm)
        
        sfLength=self.lineEdit_4.text()
        sfWidth=self.lineEdit_5.text()
        sfSize=self.lineEdit_8.text()
        sfConc=self.lineEdit_6.text()
        sfConc1=self.lineEdit_9.text()
        sfAsym=self.lineEdit_10.text()
        sfM3Long=self.lineEdit_11.text()
        sfM3Trans=self.lineEdit_12.text()
        sAlpha=self.lineEdit_13.text()
        sDist=self.lineEdit_7.text()
          
            
        res=model.predict([[float(sfLength),float(sfWidth),float(sfSize),float(sfConc),float(sfConc1),float(sfAsym),float(sfM3Long),
                            float(sfM3Trans),float(sAlpha),float(sDist)]])
        print(res)
        self.label_12.setText(str(res))
        
    def login(self):
        sfLength=self.lineEdit_4.text()
        sfWidth=self.lineEdit_5.text()
        sfSize=self.lineEdit_8.text()
        sfConc=self.lineEdit_6.text()
        sfConc1=self.lineEdit_9.text()
        sfAsym=self.lineEdit_10.text()
        sfM3Long=self.lineEdit_11.text()
        sfM3Trans=self.lineEdit_12.text()
        sAlpha=self.lineEdit_13.text()
        sDist=self.lineEdit_7.text()
          
        if len(sfLength)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fLength")
            
        elif len(sfWidth)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fWidth ")
            
        elif len(sfSize)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fSize")
            
        elif len(sfConc)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fConc")
        
        elif len(sfConc1)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fConc1")
            
        elif len(sfAsym)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fAsym")
            
        elif len(sfM3Long)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fM3Long")
            
        elif len(sfM3Trans)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fM3Trans")
            
        elif len(sAlpha)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fAlpha")
                
        elif len(sDist)<1:
            QMessageBox.information(None,"Incomplete Data","Please fill fDist")
                 
        else:
            QMessageBox.information(None,"SUCCESSFUL!!!","Data has been predicted")


        

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "pr"))
        self.label.setText(_translate("Form", "TELESCOPE SPECTRUM CLASSIFICATION"))
        self.label_2.setText(_translate("Form", "flength"))
        self.label_3.setText(_translate("Form", "fWidth"))
        self.label_4.setText(_translate("Form", "fSize"))
        self.label_5.setText(_translate("Form", "fConc"))
        self.label_6.setText(_translate("Form", "fConc1"))
        self.label_7.setText(_translate("Form", "fAsym"))
        self.label_8.setText(_translate("Form", "fM3Long"))
        self.label_9.setText(_translate("Form", "fM3Trans"))
        self.label_10.setText(_translate("Form", "fAlpha"))
        self.label_11.setText(_translate("Form", "fDist"))
        self.pushButton.setText(_translate("Form", "PREDICT"))
        self.label_12.setText(_translate("Form", "      CLASS"))


if _name_ == "_main_":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
